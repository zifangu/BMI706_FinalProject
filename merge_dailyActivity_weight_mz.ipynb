# %%
import pandas as pd
import numpy as np
import os
from scipy import stats

# %%
data_dir = "Data"
dailyActivity = pd.read_csv(os.path.join(data_dir,"dailyActivity_merged.csv"))
weightLog = pd.read_csv(os.path.join(data_dir,"weightLogInfo_merged.csv"))

# %%
dailyActivity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %%
#weightLog.head()
weightLog[weightLog.Id==1503960366]
# Out:
#            Id                  Date   WeightKg  WeightPounds   Fat    BMI  \
# 0  1503960366  5/2/2016 11:59:59 PM  52.599998    115.963147  22.0  22.65
# 1  1503960366  5/3/2016 11:59:59 PM  52.599998    115.963147   NaN  22.65
#
#    IsManualReport          LogId
# 0            True  1462233599000
# 1            True  1462319999000

# %%
# make dictionary mapping Ids to a tuple containing average BMI and weight
weightIds = weightLog.Id.unique()
weight_dict = dict()
for Id in weightIds:
    Id_info = weightLog[weightLog.Id==Id]
    mean_bmi = np.mean(Id_info['BMI'])
    mean_weightKg = np.mean(Id_info['WeightKg'])
    weight_dict[Id] = (mean_bmi,mean_weightKg)

# %%
weight_dict
# Out:
# {1503960366: (22.6499996185303, 52.5999984741211),
#  1927972279: (47.5400009155273, 133.5),
#  2873212765: (21.57000064849855, 57.0),
#  4319703577: (27.41499996185305, 72.35000228881836),
#  4558609924: (27.213999938964843, 69.63999938964844),
#  5577150313: (28.0, 90.6999969482422),
#  6962181067: (24.027999750773112, 61.553333791097),
#  8877689391: (25.48708335558574, 85.14583428700765)}

# %%
# add weight dict information to dailyActivity
dailyAct_weight = dailyActivity.copy()
dailyAct_weight.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %%
dailyAct_weight = dailyAct_weight.reindex(columns = dailyAct_weight.columns.tolist() +
                                                        ["BMI", "WeightKg"])

dailyAct_weight.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  BMI  \
# 0                   13                   328               728      1985  NaN
# 1                   19                   217               776      1797  NaN
# 2                   11                   181              1218      1776  NaN
# 3                   34                   209               726      1745  NaN
# 4                   10                   221               773      1863  NaN
#
#    WeightKg
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
for idx, row in dailyAct_weight.iterrows():
    Id = dailyAct_weight['Id'][idx]
    try:
        dailyAct_weight['BMI'] = weight_dict[Id][0]
        dailyAct_weight['WeightKg'] = weight_dict[Id][1]
    except KeyError:
        pass

dailyAct_weight.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863
#
#          BMI   WeightKg
# 0  25.487083  85.145834
# 1  25.487083  85.145834
# 2  25.487083  85.145834
# 3  25.487083  85.145834
# 4  25.487083  85.145834

# %%
# save new dataframe to .csv
processed_data_dir = "ProcessedData"
dailyAct_weight.to_csv(os.path.join(processed_data_dir,"dailyActivity_weight_merged.csv"))

# %%
# calculate each new dataframe of individual means
individuals = dailyAct_weight['Id'].unique()
indiv_dict = dict()
for person in individuals:
    indiv_dict[person] = dailyAct_weight[dailyAct_weight['Id']==person].iloc[:,2:].mean(axis=0)
indiv_dailyAct_weight = pd.DataFrame.from_dict(indiv_dict).T
indiv_dailyAct_weight.index.name='Id'
indiv_dailyAct_weight.head()
# Out:
#               TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366  12116.741935       7.809677         7.809677
# 1624580081   5743.903226       3.914839         3.914839
# 1644430081   7282.966667       5.295333         5.295333
# 1844505072   2580.064516       1.706129         1.706129
# 1927972279    916.129032       0.634516         0.634516
#
#             LoggedActivitiesDistance  VeryActiveDistance  \
# Id
# 1503960366                       0.0            2.858387
# 1624580081                       0.0            0.939355
# 1644430081                       0.0            0.730000
# 1844505072                       0.0            0.008387
# 1927972279                       0.0            0.095806
#
#             ModeratelyActiveDistance  LightActiveDistance  \
# Id
# 1503960366                  0.794194             4.152903
# 1624580081                  0.360645             2.606774
# 1644430081                  0.951000             3.609000
# 1844505072                  0.049032             1.647419
# 1927972279                  0.031290             0.507097
#
#             SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# Id
# 1503960366                 0.000000          38.709677            19.161290
# 1624580081                 0.006129           8.677419             5.806452
# 1644430081                 0.004000           9.566667            21.366667
# 1844505072                 0.000000           0.129032             1.290323
# 1927972279                 0.000000           1.322581             0.774194
#
#             LightlyActiveMinutes  SedentaryMinutes     Calories        BMI  \
# Id
# 1503960366            219.935484        848.161290  1816.419355  25.487083
# 1624580081            153.483871       1257.741935  1483.354839  25.487083
# 1644430081            178.466667       1161.866667  2811.300000  25.487083
# 1844505072            115.451613       1206.612903  1573.483871  25.487083
# 1927972279             38.580645       1317.419355  2172.806452  25.487083
#
#              WeightKg
# Id
# 1503960366  85.145834
# 1624580081  85.145834
# 1644430081  85.145834
# 1844505072  85.145834
# 1927972279  85.145834

# %%
processed_data_dir = "ProcessedData"
indiv_dailyAct_weight.to_csv(os.path.join(processed_data_dir,"indiv_dailyActivity_weight_merged.csv"))
